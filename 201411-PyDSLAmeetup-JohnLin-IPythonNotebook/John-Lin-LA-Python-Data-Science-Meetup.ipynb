# %% [markdown]
# ##This is an example of iPython notebook.  The cell is a fundamental unit.

# %% [markdown]
# As we see in the above line, the cell can be a text string.  But it can also contain code, as seen below.

# %%
import pandas as pd

# %% [markdown]
# ###Oops, looks like we don't have pandas installed.  We can go back to the shell and install pandas, or we can leverage one of the cool features of the iPython notebook to interact with the shell directly.

# %%
# !pip install pandas
# Out:
# Downloading/unpacking pandas
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):   0%  24kB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):   0%  61kB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):   2%  155kB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):   3%  237kB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):   5%  368kB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):   7%  524kB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  11%  749kB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  14%  991kB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  19%  1.3MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  22%  1.5MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  26%  1.8MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  31%  2.1MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  35%  2.4MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  39%  2.7MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  44%  2.9MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  46%  3.1MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  49%  3.3MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  54%  3.6MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  59%  4.0MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  64%  4.3MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  69%  4.6MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  73%  4.9MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  78%  5.2MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  83%  5.5MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  87%  5.8MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  91%  6.1MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  94%  6.3MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB):  99%  6.6MB
#   Downloading pandas-0.15.0-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (6.6MB): 6.6MB downloaded
# Downloading/unpacking numpy>=1.7.0 (from pandas)
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):   1%  49kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  10%  368kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  18%  667kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  28%  1.0MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  34%  1.2MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  45%  1.6MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  56%  2.0MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  66%  2.4MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  74%  2.7MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  80%  2.9MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  88%  3.2MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  98%  3.5MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB): 3.6MB downloaded
# Downloading/unpacking python-dateutil (from pandas)
#   Downloading python-dateutil-2.2.tar.gz (259kB):  12%  32kB
#   Downloading python-dateutil-2.2.tar.gz (259kB): 259kB downloaded
#   Running setup.py (path:/Users/jlin/.virtualenvs/python_data_science/build/python-dateutil/setup.py) egg_info for package python-dateutil
# Downloading/unpacking pytz>=2011k (from pandas)
#   Downloading pytz-2014.7.tar.bz2 (166kB): 166kB downloaded
#   Running setup.py (path:/Users/jlin/.virtualenvs/python_data_science/build/pytz/setup.py) egg_info for package pytz
# Downloading/unpacking six (from python-dateutil->pandas)
#   Downloading six-1.8.0-py2.py3-none-any.whl
# Installing collected packages: pandas, numpy, python-dateutil, pytz, six
#   Running setup.py install for python-dateutil
#   Running setup.py install for pytz
# Successfully installed pandas numpy python-dateutil pytz six
# Cleaning up...

# %%
import pandas as pd

# %% [markdown]
# We won't go into pandas in detail, since it has already been covered by John F.

# %% [markdown]
# The cool thing about the iPython notebook is that it is interactive.  You can interact with the content of your data step-by-step.

# %%
# !git clone https://github.com/pydata/pydata-book.git
# Out:
# Cloning into 'pydata-book'...
# remote: Counting objects: 225, done.
# Receiving objects:   5% (12/225)
# Receiving objects:   6% (14/225)
# Receiving objects:   7% (16/225)
# Receiving objects:   7% (16/225), 132.00 KiB | 125.00 KiB/s
# Receiving objects:   7% (16/225), 572.00 KiB | 271.00 KiB/s
# Receiving objects:   7% (16/225), 1.56 MiB | 508.00 KiB/s
# Receiving objects:   7% (16/225), 2.75 MiB | 668.00 KiB/s
# Receiving objects:   7% (16/225), 4.79 MiB | 1021.00 KiB/s
# Receiving objects:  12% (27/225), 4.79 MiB | 1021.00 KiB/s
# Receiving objects:  16% (36/225), 4.79 MiB | 1021.00 KiB/s
# Receiving objects:  20% (45/225), 4.79 MiB | 1021.00 KiB/s
# Receiving objects:  23% (52/225), 6.10 MiB | 1.26 MiB/s
# Receiving objects:  24% (54/225), 6.10 MiB | 1.26 MiB/s
# Receiving objects:  26% (59/225), 6.10 MiB | 1.26 MiB/s
# Receiving objects:  27% (61/225), 6.10 MiB | 1.26 MiB/s
# Receiving objects:  28% (63/225), 6.10 MiB | 1.26 MiB/s
# Receiving objects:  30% (68/225), 6.10 MiB | 1.26 MiB/s
# Receiving objects:  32% (72/225), 6.10 MiB | 1.26 MiB/s
# Receiving objects:  34% (77/225), 6.10 MiB | 1.26 MiB/s
# Receiving objects:  36% (81/225), 6.10 MiB | 1.26 MiB/s
# Receiving objects:  38% (86/225), 7.55 MiB | 1.56 MiB/s
# Receiving objects:  40% (90/225), 7.55 MiB | 1.56 MiB/s
# Receiving objects:  42% (95/225), 7.55 MiB | 1.56 MiB/s
# Receiving objects:  44% (99/225), 7.55 MiB | 1.56 MiB/s
# Receiving objects:  45% (102/225), 8.27 MiB | 1.66 MiB/s
# Receiving objects:  47% (106/225), 8.27 MiB | 1.66 MiB/s
# Receiving objects:  48% (108/225), 8.27 MiB | 1.66 MiB/s
# Receiving objects:  49% (111/225), 8.27 MiB | 1.66 MiB/s
# Receiving objects:  50% (113/225), 8.27 MiB | 1.66 MiB/s
# Receiving objects:  51% (115/225), 8.27 MiB | 1.66 MiB/s
# Receiving objects:  52% (117/225), 8.27 MiB | 1.66 MiB/s
# Receiving objects:  54% (122/225), 8.27 MiB | 1.66 MiB/s
# Receiving objects:  55% (124/225), 8.27 MiB | 1.66 MiB/s
# Receiving objects:  56% (126/225), 8.27 MiB | 1.66 MiB/s
# Receiving objects:  57% (129/225), 10.00 MiB | 1.95 MiB/s
# Receiving objects:  58% (131/225), 10.00 MiB | 1.95 MiB/s
# Receiving objects:  59% (133/225), 10.00 MiB | 1.95 MiB/s
# Receiving objects:  60% (135/225), 10.00 MiB | 1.95 MiB/s
# Receiving objects:  61% (138/225), 10.00 MiB | 1.95 MiB/s
# Receiving objects:  62% (140/225), 10.00 MiB | 1.95 MiB/s
# Receiving objects:  63% (142/225), 10.00 MiB | 1.95 MiB/s
# Receiving objects:  64% (144/225), 10.00 MiB | 1.95 MiB/s
# Receiving objects:  65% (147/225), 11.99 MiB | 2.26 MiB/s
# Receiving objects:  66% (149/225), 11.99 MiB | 2.26 MiB/s
# Receiving objects:  68% (153/225), 11.99 MiB | 2.26 MiB/s
# Receiving objects:  74% (167/225), 11.99 MiB | 2.26 MiB/s
# Receiving objects:  78% (176/225), 11.99 MiB | 2.26 MiB/s
# Receiving objects:  80% (180/225), 13.96 MiB | 2.62 MiB/s
# Receiving objects:  83% (187/225), 13.96 MiB | 2.62 MiB/s
# Receiving objects:  84% (189/225), 13.96 MiB | 2.62 MiB/s
# Receiving objects:  86% (194/225), 16.21 MiB | 2.95 MiB/s
# Receiving objects:  86% (194/225), 18.45 MiB | 2.99 MiB/s
# Receiving objects:  86% (194/225), 18.92 MiB | 2.84 MiB/s
# Receiving objects:  86% (194/225), 19.14 MiB | 2.29 MiB/s
# Receiving objects:  86% (194/225), 19.51 MiB | 1.81 MiB/s
# Receiving objects:  86% (194/225), 19.73 MiB | 1.46 MiB/s
# Receiving objects:  86% (194/225), 20.61 MiB | 852.00 KiB/s
# Receiving objects:  86% (194/225), 21.93 MiB | 632.00 KiB/s
# Receiving objects:  86% (194/225), 23.32 MiB | 886.00 KiB/s
# Receiving objects:  86% (194/225), 25.82 MiB | 1.36 MiB/s
# Receiving objects:  86% (194/225), 28.36 MiB | 1.68 MiB/s
# Receiving objects:  86% (194/225), 28.43 MiB | 1.58 MiB/s
# Receiving objects:  86% (194/225), 28.82 MiB | 1.38 MiB/s
# Receiving objects:  86% (194/225), 29.68 MiB | 1.28 MiB/s
# Receiving objects:  86% (194/225), 30.61 MiB | 965.00 KiB/s
# Receiving objects:  86% (194/225), 32.39 MiB | 861.00 KiB/s
# Receiving objects:  86% (194/225), 34.23 MiB | 1.15 MiB/s
# Receiving objects:  86% (194/225), 36.09 MiB | 1.36 MiB/s
# Receiving objects:  86% (194/225), 37.25 MiB | 1.50 MiB/s
# Receiving objects:  86% (194/225), 38.92 MiB | 1.67 MiB/s
# Receiving objects:  88% (198/225), 39.28 MiB | 1.58 MiB/s
# Receiving objects:  88% (200/225), 39.28 MiB | 1.58 MiB/s
# remote: Total 225 (delta 0), reused 0 (delta 0)
# Receiving objects: 100% (225/225), 40.06 MiB | 1.54 MiB/s, done.
# Resolving deltas:   8% (2/24)
# Resolving deltas: 100% (24/24), done.
# Checking connectivity... done.

# %%
##How to interrupt a long data step?
#Run this cell and then click on Kernel -> Interrupt on the Menu above.
range(10**10)

# %% [markdown]
# ##iPython Notebook provides programming support.

# %%
#Complete the line with a left parenthesis.
#Notice that it auto-completes the right parenthesis and displays the argument list
data = pd.read_csv

# %%
#You can also ask to see the doc string of a method by typing the question mark.
pd.read_csv?

# %% [markdown]
# ##ipython has lots of special features, such as magic commands.  For more resources, check out:
# http://ipython.org/ipython-doc/dev/interactive/tutorial.html

# %%
#One quick example:
# %timeit range(1)
# Out:
# 1000000 loops, best of 3: 220 ns per loop

# %% [markdown]
# ##There is also many cool ipython notebooks floating around.  For example, see a book that was written in iPython Notebook format.
#     http://nbviewer.ipython.org/github/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter1_Introduction/Chapter1_Introduction.ipynb
